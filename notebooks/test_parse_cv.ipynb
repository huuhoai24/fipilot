# %%
pip install docling
# Out:
# /home/hoai/user/resource/fipilot/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from docling.document_converter import DocumentConverter

source = ""  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# [INFO] 2026-05-21 16:43:22,468 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-05-21 16:43:22,477 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.8.0/onnx/PP-OCRv4/det/ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-05-21 16:43:23,823 [RapidOCR] download_file.py:82: Download size: 4.53MB
# [INFO] 2026-05-21 16:43:24,327 [RapidOCR] download_file.py:95: Successfully saved to: /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-05-21 16:43:24,329 [RapidOCR] main.py:57: Using /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-05-21 16:43:24,492 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# ...

# %%
import pdfplumber

# Open a PDF file and extract text
pdf_path = "/home/hoai/user/resource/fipilot/dataset/cv2.pdf"  # Update with your PDF path
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        print(page.extract_text())
# Out:
# NGUYEN HUU HOAI
# AI Engineer
# QuyNhonCity,Vietnam|+84359948940|Email|LinkedIn
# PROFESSIONALSUMMARY
# Proactive AI Engineer with a strong foundation in Machine Learning, Computer Vision, and Deep Learning. Ex-
# periencedinbuildingLLMintegrationsviaAzureOpenAI.Eagertoleveragetechnicalexpertiseandafast-learning
# mindsettobridgeAIresearchwithproduction-readysolutions.
# Specialties
# · StrongfoundationinMachineLearning,DeepLearning,andComputerVision.
# · Hands-onexperienceintegratingLargeLanguageModels(LLMs)andGenerativeAI(AzureOpenAI)into
# enterpriseapplications.
# · FamiliarwithSQLdatabases(CosmosDB)andclouddeployment(AzureAIServices).
# · Knowledgeofversioncontrol(Git),andAPIdesign/testingwithPostman.
# · InterestedinAppliedAI,systemoptimization,andAI-drivensoftwarearchitecture.
# · ExperiencedinbackenddevelopmentusingC#(.NET)andPython.
# TECHNICALSTACK
# · Languages:Python,SQL,R,C#
# · Frameworks&Libraries:PyTorch,TensorFlow,Scikit-learn,OpenCV,YOLO,PaddleOCR
# ...

# %%
import pymupdf

doc = pymupdf.open("/home/hoai/user/resource/fipilot/dataset/cv2.pdf")
for page in doc:
    print(page.get_text())
# Out:
# NGUYEN HUU HOAI
# AI Engineer
# Quy Nhon City, Vietnam | +84 359 948 940 | Email | LinkedIn
# PROFESSIONAL SUMMARY
# Proactive AI Engineer with a strong foundation in Machine Learning, Computer Vision, and Deep Learning. Ex-
# perienced in building LLM integrations via Azure OpenAI. Eager to leverage technical expertise and a fast-learning
# mindset to bridge AI research with production-ready solutions.
# Specialties
# ·
# Strong foundation in Machine Learning, Deep Learning, and Computer Vision.
# ·
# Hands-on experience integrating Large Language Models (LLMs) and Generative AI (Azure OpenAI) into
# enterprise applications.
# ·
# Familiar with SQL databases (CosmosDB) and cloud deployment (Azure AI Services).
# ·
# Knowledge of version control (Git), and API design/testing with Postman.
# ·
# Interested in Applied AI, system optimization, and AI-driven software architecture.
# ·
# Experienced in backend development using C# (.NET) and Python.
# TECHNICAL STACK
# ·
# ...

# %%
import pymupdf4llm

# md = pymupdf4llm.to_markdown("/home/hoai/user/resource/fipilot/dataset/cv2.pdf")
md = pymupdf4llm.to_markdown("/home/hoai/user/resource/fipilot/dataset/ac-cv-2411.pdf")
# Pass directly to your LLM or vector store
print(md)
# Out:
# **Abhi it Cham anerkar j p**
#
# **CV**
#
# |Department of Mathematics, 1S-230||The Graduate Center, CUNY, 4307|The Graduate Center, CUNY, 4307|
# |---|---|---|---|
# |College of Staten Island, CUNY|||365 5th Avenue|
# |Staten Island, NY 10314|||New York, NY 10016|
# |phone: (718) 982-3613 fax: (718) 982-3631|||phone: (212) 817 8554|
# |`abhijit@math.csi.cuny.edu`|`http://www.math.csi.cuny.edu/~abhijit`|||
# |**Education**||||
# |Ph.D Mathematics, Columbia University|||2003|
# |Dissertation title: A-polynomials and Bloch invariants of hyperbolic 3-manifolds||||
# |Advisor: Walter Neumann||||
# |M.Sc. Mathematics, Bombay University|||1997|
# |B.Sc. Mathematics, Bombay University|||1995|
# |**Appointments**||||
# |Acting Chairperson, Department of Mathematics, CSI,||CUNY|Fall 2023, Fall 2024|
# |Columbia University, Visiting Scholar|||2022–23|
# |College of Staten Island, CUNY, Professor|||2018-current|
# |College of Staten Island, CUNY, Associate Professor|||2012–18|
# ...

# %%
import pymupdf

doc = pymupdf.open("/home/hoai/user/resource/fipilot/dataset/--resume-28.pdf")
page = doc[0]

blocks = page.get_text("dict")["blocks"]
for block in blocks:
    if block["type"] == 0:  # text block
        for line in block["lines"]:
            for span in line["spans"]:
                print(f"{span['text']!r}  font={span['font']}  size={span['size']:.1f}")
# Out:
# '          Mr.Montri Chuencharoen '  font=AngsanaUPC  size=48.0
# 'JOB APPLICATION'  font=Calibri-Bold  size=14.0
# ': '  font=Calibri  size=11.0
# ' '  font=Calibri  size=12.0
# 'SALARY:'  font=Calibri-Bold  size=14.0
# ' '  font=Calibri  size=11.0
# 'negotiate'  font=Calibri-Bold  size=14.0
# ' '  font=CordiaNew-Bold  size=14.0
# 'PERSONAL INFORMATION '  font=Calibri-Bold  size=14.0
# 'Residential Address'  font=Calibri-Bold  size=11.0
# ': 24/509 Moo.1 Viphavadee-Rangsit Rd., Don Mueang, Bangkok 10210. Thailand. '  font=Calibri  size=11.0
# 'Mobile'  font=Calibri-Bold  size=11.0
# ': 098-264-4250 '  font=Calibri  size=11.0
# 'E-mail'  font=Calibri-Bold  size=11.0
# ' : ch_moc@hotmail.com ,  montri.ch75@gmail.com '  font=Calibri  size=11.0
# 'Date of Birth'  font=Calibri-Bold  size=11.0
# ': 2 May 1975 '  font=Calibri  size=11.0
# 'Nationality'  font=Calibri-Bold  size=11.0
# ': Thai '  font=Calibri  size=11.0
# 'Age'  font=Calibri-Bold  size=11.0
# ...
