# %%
# %load_ext autoreload
# %autoreload 2

from config import cfg
from huggingface_hub import login
login(token=cfg.hf_token)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-3B-Instruct")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:997, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     996 else:
# --> 997     return _hf_hub_download_to_cache_dir(
#     998         # Destination
#     999         cache_dir=cache_dir,
#    1000         # File info
#    1001         repo_id=repo_id,
#    1002         filename=filename,
#    1003         repo_type=repo_type,
#    1004         revision=revision,
#    1005         # HTTP info
#    1006         endpoint=endpoint,
#    1007         etag_timeout=etag_timeout,
#    1008         headers=hf_headers,
#    1009         token=token,
#    1010         # Additional options
#    1011         local_files_only=local_files_only,
#    1012         force_download=force_download,
#    1013         tqdm_class=tqdm_class,
#    1014         dry_run=dry_run,
#    1015     )
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1148, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1147     if head_call_error is not None:
# -> 1148         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1150 # From now on, etag, commit_hash, url and size are not None.
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1782, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1777 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1778     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1779 ):
#    1780     # Repo not found or gated => let's raise the actual error
#    1781     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1782     raise head_call_error
#    1783 else:
#    1784     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1669, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1668 try:
# -> 1669     metadata = get_hf_file_metadata(
#    1670         url=url,
#    1671         timeout=etag_timeout,
#    1672         headers=headers,
#    1673         token=token,
#    1674         endpoint=endpoint,
#    1675         retry_on_errors=retry_on_errors,
#    1676     )
#    1677 except RemoteEntryNotFoundError as http_error:
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1591, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1590 # Retrieve metadata
# -> 1591 response = _httpx_follow_relative_redirects_with_backoff(
#    1592     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1593 )
#    1594 hf_raise_for_status(response)
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:692, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     685 response = http_backoff(
#     686     method=method,
#     687     url=url,
#    (...)    690     **no_retry_kwargs,
#     691 )
# --> 692 hf_raise_for_status(response)
#     694 # Check if response is a relative redirect
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:787, in hf_raise_for_status(response, endpoint_name)
#     784     message = (
#     785         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     786     )
# --> 787     raise _format(GatedRepoError, message, response, repo_type=repo_type, repo_id=repo_id) from e
#     789 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-6a057988-15272c232c236cb374119996;535df2df-926d-4aca-add2-54b99ee12d00)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-3B-Instruct is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-3B-Instruct")
#       4 messages = [
#       5     {"role": "user", "content": "Who are you?"},
#       6 ]
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/pipelines/__init__.py:900, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     897                 if not os.path.exists(model) or not os.path.exists(os.path.join(model, CONFIG_NAME)):
#     898                     model = adapter_config["base_model_name_or_path"]
# --> 900     config = AutoConfig.from_pretrained(
#     901         model, _from_pipeline=task, code_revision=code_revision, **hub_kwargs, **model_kwargs
#     902     )
#     903     hub_kwargs["_commit_hash"] = config._commit_hash
#     905 custom_tasks = {}
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:374, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     371 trust_remote_code = kwargs.pop("trust_remote_code", None)
#     372 code_revision = kwargs.pop("code_revision", None)
# --> 374 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     375 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     376 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/configuration_utils.py:682, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     680 original_kwargs = copy.deepcopy(kwargs)
#     681 # Get config dict associated with the base config file
# --> 682 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     683 if config_dict is None:
#     684     return {}, kwargs
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/configuration_utils.py:737, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     733 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     735 try:
#     736     # Load from local folder or from cache or download from model Hub and cache
# --> 737     resolved_config_file = cached_file(
#     738         pretrained_model_name_or_path,
#     739         configuration_file,
#     740         cache_dir=cache_dir,
#     741         force_download=force_download,
#     742         proxies=proxies,
#     743         local_files_only=local_files_only,
#     744         token=token,
#     745         user_agent=user_agent,
#     746         revision=revision,
#     747         subfolder=subfolder,
#     748         _commit_hash=commit_hash,
#     749     )
#     750     if resolved_config_file is None:
#     751         return None, kwargs
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)    276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:488, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     486     if not _raise_exceptions_for_gated_repo:
#     487         return None
# --> 488     raise OSError(
#     489         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     490         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     491     ) from e
#     492 elif isinstance(e, LocalEntryNotFoundError):
#     493     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct.
# 403 Client Error. (Request ID: Root=1-6a057988-15272c232c236cb374119996;535df2df-926d-4aca-add2-54b99ee12d00)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-3B-Instruct is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct to ask for access.

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="Qwen/Qwen3-4B-Instruct-2507")
messages = [
    {"role": "user", "content": "you can understand vietnamese"},
]
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
#       3
# ----> 4 pipe = pipeline("text-generation", model="Qwen/Qwen3-4B-Instruct-2507")
#       5 messages = [
#       6     {"role": "user", "content": "you can understand vietnamese"},
#       7 ]
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/pipelines/__init__.py:1002, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1000 if isinstance(model, str):
#    1001     model_classes = targeted_task["pt"]
# -> 1002     model = load_model(
#    1003         adapter_path if adapter_path is not None else model,
#    1004         model_classes=model_classes,
#    1005         config=config,
#    1006         task=task,
#    1007         **hub_kwargs,
#    1008         **model_kwargs,
#    1009     )
#    1011 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1013 if pipeline_class is None:
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:232, in load_model(model, config, model_classes, task, **model_kwargs)
#     229 kwargs = model_kwargs.copy()
#     231 try:
# --> 232     model = model_class.from_pretrained(model, **kwargs)
#     233     # Stop loading on the first successful load.
#     234     break
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:405, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     403         if parent_quant is not None:
#     404             config.quantization_config = parent_quant
# --> 405     return model_class.from_pretrained(
#     406         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     407     )
#     408 raise ValueError(
#     409     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     410     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     411 )
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:4153, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4148     logger.warning_once(
#    4149         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4150     )
#    4151     use_kernels = True
# -> 4153 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4154     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4155     variant=variant,
#    4156     gguf_file=gguf_file,
#    4157     use_safetensors=use_safetensors,
#    4158     download_kwargs=download_kwargs_with_commit,
#    4159     user_agent=user_agent,
#    4160     is_remote_code=cls.is_remote_code(),
#    4161     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4162     tqdm_class=tqdm_class,
#    4163 )
#    4165 is_quantized = hf_quantizer is not None
#    4167 # Find the correct dtype based on current state
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:797, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     795 sharded_metadata = None
#     796 if is_sharded:
# --> 797     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#     798         pretrained_model_name_or_path,
#     799         resolved_archive_file,
#     800         cache_dir=cache_dir,
#     801         force_download=force_download,
#     802         proxies=proxies,
#     803         local_files_only=local_files_only,
#     804         token=token,
#     805         user_agent=user_agent,
#     806         revision=revision,
#     807         subfolder=subfolder,
#     808         _commit_hash=commit_hash,
#     809         tqdm_class=tqdm_class,
#     810     )
#     811 else:
#     812     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:879, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, subfolder, _commit_hash, tqdm_class, **deprecated_kwargs)
#     875     return shard_filenames, sharded_metadata
#     877 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#     878 # or download the files
# --> 879 cached_filenames = cached_files(
#     880     pretrained_model_name_or_path,
#     881     shard_filenames,
#     882     cache_dir=cache_dir,
#     883     force_download=force_download,
#     884     proxies=proxies,
#     885     local_files_only=local_files_only,
#     886     token=token,
#     887     user_agent=user_agent,
#     888     revision=revision,
#     889     subfolder=subfolder,
#     890     _commit_hash=_commit_hash,
#     891     tqdm_class=tqdm_class,
#     892 )
#     894 return cached_filenames, sharded_metadata
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     422         hf_hub_download(
#     423             path_or_repo_id,
#     424             filenames[0],
#    (...)    434             tqdm_class=tqdm_class,
#     435         )
#     436     else:
# --> 437         snapshot_download(
#     438             path_or_repo_id,
#     439             allow_patterns=full_filenames,
#     440             repo_type=repo_type,
#     441             revision=revision,
#     442             cache_dir=cache_dir,
#     443             user_agent=user_agent,
#     444             force_download=force_download,
#     445             proxies=proxies,
#     446             token=token,
#     447             local_files_only=local_files_only,
#     448             tqdm_class=tqdm_class,
#     449         )
#     451 except Exception as e:
#     452     # We cannot recover from them
#     453     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/huggingface_hub/_snapshot_download.py:455, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, dry_run)
#     433 def _inner_hf_hub_download(repo_file: str) -> None:
#     434     results.append(
#     435         hf_hub_download(  # type: ignore
#     436             repo_id,
#    (...)    452         )
#     453     )
# --> 455 thread_map(
#     456     _inner_hf_hub_download,
#     457     filtered_repo_files,
#     458     desc=tqdm_desc,
#     459     max_workers=max_workers,
#     460     tqdm_class=tqdm_class,
#     461 )
#     463 bytes_progress.set_description("Download complete")
#     465 if dry_run:
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File ~/user/resource/fipilot/.venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
