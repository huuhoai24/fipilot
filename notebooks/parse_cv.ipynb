# %%
from docling.document_converter import DocumentConverter

source = "/home/hoai/user/resource/fipilot/dataset/image.png"  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# [INFO] 2026-05-19 07:55:52,199 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-19 07:55:52,202 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-05-19 07:55:52,283 [RapidOCR] download_file.py:60: File exists and is valid: /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-19 07:55:52,284 [RapidOCR] main.py:50: Using /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-05-19 07:55:52,760 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-19 07:55:52,762 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-05-19 07:55:52,769 [RapidOCR] download_file.py:60: File exists and is valid: /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-05-19 07:55:52,770 [RapidOCR] main.py:50: Using /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-05-19 07:55:52,913 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-05-19 07:55:52,914 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-05-19 07:55:53,059 [RapidOCR] download_file.py:60: File exists and is valid: /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_rec_mobile.pth
# [INFO] 2026-05-19 07:55:53,060 [RapidOCR] main.py:50: Using /home/hoai/user/resource/fipilot/.venv/lib/python3.12/site-packages/rapidocr/models/ch_PP-OCRv4_rec_mobile.pth
# Loading weights:   0%|          | 0/770 [00:00<?, ?it/s]
